# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 736

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | knysna
# Processing Record 4 of Set 1 | thompson
# Processing Record 5 of Set 1 | kisangani
# Processing Record 6 of Set 1 | kichera
# Processing Record 7 of Set 1 | balad
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | mount gambier
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | lavrentiya
# Processing Record 13 of Set 1 | los llanos de aridane
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | maridi
# Processing Record 20 of Set 1 | coquimbo
# Processing Record 21 of Set 1 | pervomayskoye
# Processing Record 22 of Set 1 | bucerias
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | hami
# Processing Record 30 of Set 1 | sandviken
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | aripuana
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | abu samrah
# Processing Record 35 of Set 1 | saint andrews
# Processing Record 36 of Set 1 | skovorodino
# Processing Record 37 of Set 1 | orneta
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | hambantota
# Processing Record 40 of Set 1 | lere
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | half moon bay
# Processing Record 44 of Set 1 | jurilovca
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | severnyy
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 1 | maldonado
# Processing Record 1 of Set 2 | carauari
# Processing Record 2 of Set 2 | gravdal
# Processing Record 3 of Set 2 | kabare
# Processing Record 4 of Set 2 | longyearbyen
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | lorengau
# Processing Record 9 of Set 2 | vestmannaeyjar
# Processing Record 10 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 11 of Set 2 | port blair
# Processing Record 12 of Set 2 | anage
# Processing Record 13 of Set 2 | russell
# Processing Record 14 of Set 2 | hamilton
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | la asuncion
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | vuktyl
# Processing Record 19 of Set 2 | san angelo
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | pokaran
# Processing Record 23 of Set 2 | saint-pierre
# Processing Record 24 of Set 2 | sovetskiy
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | kodiak
# Processing Record 27 of Set 2 | ransang
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 2 | baiyin
# Processing Record 31 of Set 2 | odweyne
# Processing Record 32 of Set 2 | cockburn town
# Processing Record 33 of Set 2 | temyasovo
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | saint-philippe
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | rock sound
# Processing Record 38 of Set 2 | hirado
# Processing Record 39 of Set 2 | ocean city
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | alofi
# Processing Record 42 of Set 2 | atar
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | kikwit
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | tahoua
# Processing Record 47 of Set 2 | labuhan
# Processing Record 48 of Set 2 | alto araguaia
# Processing Record 49 of Set 2 | briancon
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | omboue
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | goderich
# Processing Record 4 of Set 3 | sakakah
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | xihua
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | prado
# Processing Record 9 of Set 3 | andreiasu de jos
# Processing Record 10 of Set 3 | bredy
# Processing Record 11 of Set 3 | paita
# Processing Record 12 of Set 3 | karratha
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | busselton
# Processing Record 15 of Set 3 | san carlos del zulia
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | sibolga
# Processing Record 18 of Set 3 | nikolskoye
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 3 | dese
# Processing Record 23 of Set 3 | faanui
# Processing Record 24 of Set 3 | mujiayingzi
# Processing Record 25 of Set 3 | pokhara
# Processing Record 26 of Set 3 | hailar
# Processing Record 27 of Set 3 | sinnamary
# Processing Record 28 of Set 3 | quatre cocos
# Processing Record 29 of Set 3 | kamenskiy
# Processing Record 30 of Set 3 | george town
# Processing Record 31 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | luz
# Processing Record 33 of Set 3 | payakumbuh
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | russkaya polyana
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | kaliyaganj
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | kidal
# Processing Record 40 of Set 3 | castro
# Processing Record 41 of Set 3 | pundaguitan
# Processing Record 42 of Set 3 | souillac
# Processing Record 43 of Set 3 | flinders
# Processing Record 44 of Set 3 | hervey bay
# Processing Record 45 of Set 3 | mackay
# Processing Record 46 of Set 3 | banda aceh
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | presidente medici
# Processing Record 49 of Set 3 | florianopolis
# Processing Record 50 of Set 3 | muisne
# Processing Record 1 of Set 4 | bandarbeyla
# Processing Record 2 of Set 4 | port macquarie
# Processing Record 3 of Set 4 | sisimiut
# Processing Record 4 of Set 4 | hay river
# Processing Record 5 of Set 4 | khorixas
# Processing Record 6 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 4 | sorland
# Processing Record 8 of Set 4 | wilmington
# Processing Record 9 of Set 4 | saint george
# Processing Record 10 of Set 4 | port hedland
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | kavaratti
# Processing Record 13 of Set 4 | vandoeuvre-les-nancy
# Processing Record 14 of Set 4 | binzhou
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | okmulgee
# Processing Record 17 of Set 4 | bokaa
# Processing Record 18 of Set 4 | schlitz
# Processing Record 19 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 4 | hofn
# Processing Record 21 of Set 4 | gazli
# Processing Record 22 of Set 4 | itarema
# Processing Record 23 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 4 | kavieng
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | te anau
# Processing Record 27 of Set 4 | maneadero
# Processing Record 28 of Set 4 | zlatoustovsk
# City not found. Skipping...
# Processing Record 29 of Set 4 | sao joao da barra
# Processing Record 30 of Set 4 | yellowknife
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | bredasdorp
# Processing Record 34 of Set 4 | arrifes
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | huarmey
# Processing Record 37 of Set 4 | umm kaddadah
# Processing Record 38 of Set 4 | brigantine
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | fairbanks
# Processing Record 41 of Set 4 | isangel
# Processing Record 42 of Set 4 | east london
# Processing Record 43 of Set 4 | chernyshevskiy
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | vila velha
# Processing Record 46 of Set 4 | copiapo
# Processing Record 47 of Set 4 | villa bruzual
# Processing Record 48 of Set 4 | guayaramerin
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | guadalupe victoria
# Processing Record 1 of Set 5 | lagoa
# Processing Record 2 of Set 5 | georgetown
# Processing Record 3 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 5 | straumen
# Processing Record 5 of Set 5 | morris
# Processing Record 6 of Set 5 | puerto ayora
# Processing Record 7 of Set 5 | langsa
# Processing Record 8 of Set 5 | san patricio
# Processing Record 9 of Set 5 | koshurnikovo
# Processing Record 10 of Set 5 | upernavik
# Processing Record 11 of Set 5 | ous
# Processing Record 12 of Set 5 | kropotkin
# Processing Record 13 of Set 5 | caravelas
# Processing Record 14 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 5 | skjervoy
# Processing Record 16 of Set 5 | mlonggo
# Processing Record 17 of Set 5 | lake charles
# Processing Record 18 of Set 5 | cherskiy
# Processing Record 19 of Set 5 | taburao
# City not found. Skipping...
# Processing Record 20 of Set 5 | kamwenge
# Processing Record 21 of Set 5 | bengkulu
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | vermilion
# Processing Record 24 of Set 5 | gebog
# Processing Record 25 of Set 5 | tiksi
# Processing Record 26 of Set 5 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 5 | wanning
# Processing Record 28 of Set 5 | mnogovershinnyy
# Processing Record 29 of Set 5 | port-cartier
# Processing Record 30 of Set 5 | broken hill
# Processing Record 31 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | tongliao
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | floro
# Processing Record 36 of Set 5 | cabedelo
# Processing Record 37 of Set 5 | saint anthony
# Processing Record 38 of Set 5 | faya
# Processing Record 39 of Set 5 | alugan
# Processing Record 40 of Set 5 | manaus
# Processing Record 41 of Set 5 | barwani
# Processing Record 42 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 43 of Set 5 | maragogi
# Processing Record 44 of Set 5 | fortuna
# Processing Record 45 of Set 5 | paragould
# Processing Record 46 of Set 5 | derzhavinsk
# Processing Record 47 of Set 5 | srednekolymsk
# Processing Record 48 of Set 5 | norman wells
# Processing Record 49 of Set 5 | coruripe
# Processing Record 50 of Set 5 | behshahr
# Processing Record 1 of Set 6 | nizhneangarsk
# Processing Record 2 of Set 6 | lazaro cardenas
# Processing Record 3 of Set 6 | ovre ardal
# Processing Record 4 of Set 6 | san juan
# Processing Record 5 of Set 6 | vilcun
# Processing Record 6 of Set 6 | den helder
# Processing Record 7 of Set 6 | soure
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 11 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 6 | luanda
# Processing Record 13 of Set 6 | larsnes
# Processing Record 14 of Set 6 | grand island
# Processing Record 15 of Set 6 | doha
# Processing Record 16 of Set 6 | kaitangata
# Processing Record 17 of Set 6 | shenjiamen
# Processing Record 18 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 6 | tshikapa
# Processing Record 21 of Set 6 | petropavlovskoye
# Processing Record 22 of Set 6 | esperance
# Processing Record 23 of Set 6 | byron bay
# Processing Record 24 of Set 6 | arlit
# Processing Record 25 of Set 6 | acajutla
# Processing Record 26 of Set 6 | bataraza
# City not found. Skipping...
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | evensk
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | kalmunai
# Processing Record 31 of Set 6 | nome
# Processing Record 32 of Set 6 | san quintin
# Processing Record 33 of Set 6 | nkhata bay
# Processing Record 34 of Set 6 | batagay-alyta
# Processing Record 35 of Set 6 | terrace
# Processing Record 36 of Set 6 | linqiong
# Processing Record 37 of Set 6 | phan thiet
# Processing Record 38 of Set 6 | pombas
# Processing Record 39 of Set 6 | andra
# Processing Record 40 of Set 6 | olinda
# Processing Record 41 of Set 6 | tiznit
# Processing Record 42 of Set 6 | cape town
# Processing Record 43 of Set 6 | nueva loja
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | singaraja
# Processing Record 46 of Set 6 | stornoway
# Processing Record 47 of Set 6 | aksu
# Processing Record 48 of Set 6 | grindavik
# Processing Record 49 of Set 6 | mayumba
# Processing Record 50 of Set 6 | diamantino
# Processing Record 1 of Set 7 | komsomolskiy
# Processing Record 2 of Set 7 | mattru
# Processing Record 3 of Set 7 | mogadishu
# Processing Record 4 of Set 7 | elliot lake
# Processing Record 5 of Set 7 | bhag
# Processing Record 6 of Set 7 | praya
# Processing Record 7 of Set 7 | richards bay
# Processing Record 8 of Set 7 | hirara
# Processing Record 9 of Set 7 | falun
# Processing Record 10 of Set 7 | derazhnya
# Processing Record 11 of Set 7 | yining
# Processing Record 12 of Set 7 | dunedin
# Processing Record 13 of Set 7 | yongchang
# Processing Record 14 of Set 7 | safford
# Processing Record 15 of Set 7 | yerbogachen
# Processing Record 16 of Set 7 | chifeng
# Processing Record 17 of Set 7 | belmonte
# Processing Record 18 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 7 | syamzha
# Processing Record 20 of Set 7 | panguna
# Processing Record 21 of Set 7 | katangli
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | necochea
# Processing Record 24 of Set 7 | iqaluit
# Processing Record 25 of Set 7 | beyneu
# Processing Record 26 of Set 7 | inirida
# Processing Record 27 of Set 7 | bethel
# Processing Record 28 of Set 7 | yei
# Processing Record 29 of Set 7 | bondo
# Processing Record 30 of Set 7 | batemans bay
# Processing Record 31 of Set 7 | mount isa
# Processing Record 32 of Set 7 | yeppoon
# Processing Record 33 of Set 7 | boma
# Processing Record 34 of Set 7 | codrington
# Processing Record 35 of Set 7 | morehead
# Processing Record 36 of Set 7 | tashla
# Processing Record 37 of Set 7 | rawson
# Processing Record 38 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 7 | tigil
# Processing Record 40 of Set 7 | zerbst
# Processing Record 41 of Set 7 | van
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | nouadhibou
# Processing Record 44 of Set 7 | nombre de dios
# Processing Record 45 of Set 7 | moree
# Processing Record 46 of Set 7 | kirakira
# Processing Record 47 of Set 7 | pirojpur
# Processing Record 48 of Set 7 | saskylakh
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | yarmouth
# Processing Record 1 of Set 8 | abu kamal
# Processing Record 2 of Set 8 | eureka
# Processing Record 3 of Set 8 | urdoma
# Processing Record 4 of Set 8 | mardin
# Processing Record 5 of Set 8 | matara
# Processing Record 6 of Set 8 | atlantic city
# Processing Record 7 of Set 8 | leningradskiy
# Processing Record 8 of Set 8 | date
# Processing Record 9 of Set 8 | husavik
# Processing Record 10 of Set 8 | ostrovnoy
# Processing Record 11 of Set 8 | lata
# Processing Record 12 of Set 8 | mortka
# Processing Record 13 of Set 8 | smithers
# Processing Record 14 of Set 8 | lashio
# Processing Record 15 of Set 8 | jalalabad
# Processing Record 16 of Set 8 | petrivka
# Processing Record 17 of Set 8 | leshukonskoye
# Processing Record 18 of Set 8 | ende
# Processing Record 19 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 8 | davila
# Processing Record 21 of Set 8 | airai
# Processing Record 22 of Set 8 | liverpool
# Processing Record 23 of Set 8 | asfi
# Processing Record 24 of Set 8 | djambala
# Processing Record 25 of Set 8 | si satchanalai
# Processing Record 26 of Set 8 | vostok
# Processing Record 27 of Set 8 | la rioja
# Processing Record 28 of Set 8 | teacapan
# Processing Record 29 of Set 8 | nenjiang
# Processing Record 30 of Set 8 | petauke
# Processing Record 31 of Set 8 | shalya
# Processing Record 32 of Set 8 | denpasar
# Processing Record 33 of Set 8 | guerrero negro
# Processing Record 34 of Set 8 | batagay
# Processing Record 35 of Set 8 | san cristobal
# Processing Record 36 of Set 8 | luangwa
# Processing Record 37 of Set 8 | nueve de julio
# Processing Record 38 of Set 8 | lampazos de naranjo
# Processing Record 39 of Set 8 | islampur
# Processing Record 40 of Set 8 | poum
# Processing Record 41 of Set 8 | luba
# Processing Record 42 of Set 8 | nuuk
# Processing Record 43 of Set 8 | altay
# Processing Record 44 of Set 8 | kruisfontein
# Processing Record 45 of Set 8 | henderson
# Processing Record 46 of Set 8 | buchanan
# Processing Record 47 of Set 8 | zhanaozen
# Processing Record 48 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | ano kastritsion
# Processing Record 1 of Set 9 | hillsboro
# Processing Record 2 of Set 9 | itoman
# Processing Record 3 of Set 9 | talnakh
# Processing Record 4 of Set 9 | monrovia
# Processing Record 5 of Set 9 | anchorage
# Processing Record 6 of Set 9 | teya
# Processing Record 7 of Set 9 | hornepayne
# Processing Record 8 of Set 9 | abu dhabi
# Processing Record 9 of Set 9 | boa vista
# Processing Record 10 of Set 9 | gornozavodsk
# Processing Record 11 of Set 9 | ulaangom
# Processing Record 12 of Set 9 | montrose
# Processing Record 13 of Set 9 | niimi
# Processing Record 14 of Set 9 | krapina
# Processing Record 15 of Set 9 | bathsheba
# Processing Record 16 of Set 9 | dingle
# Processing Record 17 of Set 9 | kirensk
# Processing Record 18 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 9 | marsh harbour
# Processing Record 20 of Set 9 | kalengwa
# Processing Record 21 of Set 9 | cidreira
# Processing Record 22 of Set 9 | hamois
# Processing Record 23 of Set 9 | geraldton
# Processing Record 24 of Set 9 | berdigestyakh
# Processing Record 25 of Set 9 | beira
# Processing Record 26 of Set 9 | coronado
# Processing Record 27 of Set 9 | constitucion
# Processing Record 28 of Set 9 | oksfjord
# Processing Record 29 of Set 9 | wencheng
# Processing Record 30 of Set 9 | kedainiai
# Processing Record 31 of Set 9 | kaitong
# Processing Record 32 of Set 9 | muros
# Processing Record 33 of Set 9 | gat
# Processing Record 34 of Set 9 | basco
# Processing Record 35 of Set 9 | slave lake
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | dakar
# Processing Record 38 of Set 9 | chamalieres
# Processing Record 39 of Set 9 | ust-ishim
# Processing Record 40 of Set 9 | klaksvik
# Processing Record 41 of Set 9 | tilichiki
# Processing Record 42 of Set 9 | alamogordo
# Processing Record 43 of Set 9 | eskil
# Processing Record 44 of Set 9 | comodoro rivadavia
# Processing Record 45 of Set 9 | carutapera
# Processing Record 46 of Set 9 | cayenne
# Processing Record 47 of Set 9 | deputatskiy
# Processing Record 48 of Set 9 | twin falls
# Processing Record 49 of Set 9 | vardo
# Processing Record 50 of Set 9 | saint-joseph
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | biak
# Processing Record 4 of Set 10 | austin
# Processing Record 5 of Set 10 | olga
# Processing Record 6 of Set 10 | okha
# Processing Record 7 of Set 10 | alice springs
# Processing Record 8 of Set 10 | omaruru
# Processing Record 9 of Set 10 | ahipara
# Processing Record 10 of Set 10 | rio gallegos
# Processing Record 11 of Set 10 | vilhena
# Processing Record 12 of Set 10 | alakurtti
# Processing Record 13 of Set 10 | zhigansk
# Processing Record 14 of Set 10 | savinskiy
# Processing Record 15 of Set 10 | maniitsoq
# Processing Record 16 of Set 10 | khani
# Processing Record 17 of Set 10 | teeli
# Processing Record 18 of Set 10 | salamanca
# Processing Record 19 of Set 10 | grand gaube
# Processing Record 20 of Set 10 | lohkva
# Processing Record 21 of Set 10 | kulhudhuffushi
# Processing Record 22 of Set 10 | sioux lookout
# Processing Record 23 of Set 10 | kurilsk
# Processing Record 24 of Set 10 | morondava
# Processing Record 25 of Set 10 | zuwarah
# Processing Record 26 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 10 | aswan
# Processing Record 28 of Set 10 | gao
# Processing Record 29 of Set 10 | lasa
# Processing Record 30 of Set 10 | disna
# Processing Record 31 of Set 10 | newark
# Processing Record 32 of Set 10 | nieuw amsterdam
# Processing Record 33 of Set 10 | alyangula
# Processing Record 34 of Set 10 | belyy yar
# Processing Record 35 of Set 10 | maryville
# Processing Record 36 of Set 10 | molina
# Processing Record 37 of Set 10 | yalutorovsk
# Processing Record 38 of Set 10 | xining
# Processing Record 39 of Set 10 | wadi maliz
# Processing Record 40 of Set 10 | warrnambool
# Processing Record 41 of Set 10 | reichenau
# Processing Record 42 of Set 10 | kamaishi
# Processing Record 43 of Set 10 | arroyo
# Processing Record 44 of Set 10 | umm lajj
# Processing Record 45 of Set 10 | rocha
# Processing Record 46 of Set 10 | nemuro
# Processing Record 47 of Set 10 | awbari
# Processing Record 48 of Set 10 | sur
# Processing Record 49 of Set 10 | turinskaya sloboda
# Processing Record 50 of Set 10 | salinas
# Processing Record 1 of Set 11 | neos marmaras
# Processing Record 2 of Set 11 | saint-gilles
# Processing Record 3 of Set 11 | gamba
# Processing Record 4 of Set 11 | bambanglipuro
# Processing Record 5 of Set 11 | severo-kurilsk
# Processing Record 6 of Set 11 | shitanjing
# Processing Record 7 of Set 11 | chase
# Processing Record 8 of Set 11 | ponta delgada
# Processing Record 9 of Set 11 | huazolotitlan
# City not found. Skipping...
# Processing Record 10 of Set 11 | maarianhamina
# Processing Record 11 of Set 11 | mazara del vallo
# Processing Record 12 of Set 11 | essenbach
# Processing Record 13 of Set 11 | camacha
# Processing Record 14 of Set 11 | amara
# Processing Record 15 of Set 11 | catamarca
# Processing Record 16 of Set 11 | henties bay
# Processing Record 17 of Set 11 | leon
# Processing Record 18 of Set 11 | oktyabrskoye
# Processing Record 19 of Set 11 | nouakchott
# Processing Record 20 of Set 11 | vestmanna
# Processing Record 21 of Set 11 | la ronge
# Processing Record 22 of Set 11 | esil
# Processing Record 23 of Set 11 | taksimo
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 11 | chabahar
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | hovd
# Processing Record 29 of Set 11 | qasigiannguit
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | troitskoye
# Processing Record 32 of Set 11 | ukiah
# Processing Record 33 of Set 11 | paamiut
# Processing Record 34 of Set 11 | otane
# Processing Record 35 of Set 11 | tuatapere
# Processing Record 36 of Set 11 | gubkinskiy
# Processing Record 37 of Set 11 | laem sing
# Processing Record 38 of Set 11 | tigzirt
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | tapiramuta
# Processing Record 41 of Set 11 | valdivia
# Processing Record 42 of Set 11 | udachnyy
# Processing Record 43 of Set 11 | portland
# Processing Record 44 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 11 | rincon
# Processing Record 46 of Set 11 | akcakoca
# Processing Record 47 of Set 11 | vestbygda
# City not found. Skipping...
# Processing Record 48 of Set 11 | dubai
# Processing Record 49 of Set 11 | formosa
# Processing Record 50 of Set 11 | novobeysugskaya
# Processing Record 1 of Set 12 | payo
# Processing Record 2 of Set 12 | lermontovka
# Processing Record 3 of Set 12 | diffa
# Processing Record 4 of Set 12 | atambua
# Processing Record 5 of Set 12 | prozor
# Processing Record 6 of Set 12 | ucluelet
# Processing Record 7 of Set 12 | mayo
# Processing Record 8 of Set 12 | lola
# Processing Record 9 of Set 12 | tabas
# Processing Record 10 of Set 12 | ketchikan
# Processing Record 11 of Set 12 | mezen
# Processing Record 12 of Set 12 | gushikawa
# Processing Record 13 of Set 12 | herat
# Processing Record 14 of Set 12 | college
# Processing Record 15 of Set 12 | tres arroyos
# Processing Record 16 of Set 12 | nelson bay
# Processing Record 17 of Set 12 | uarini
# Processing Record 18 of Set 12 | puerto baquerizo moreno
# Processing Record 19 of Set 12 | madimba
# Processing Record 20 of Set 12 | kutum
# Processing Record 21 of Set 12 | nsanje
# Processing Record 22 of Set 12 | wajir
# Processing Record 23 of Set 12 | songjianghe
# Processing Record 24 of Set 12 | rio verde de mato grosso
# Processing Record 25 of Set 12 | korla
# Processing Record 26 of Set 12 | charters towers
# Processing Record 27 of Set 12 | evora
# Processing Record 28 of Set 12 | ekhabi
# Processing Record 29 of Set 12 | gizo
# Processing Record 30 of Set 12 | likasi
# Processing Record 31 of Set 12 | thinadhoo
# Processing Record 32 of Set 12 | baykit
# Processing Record 33 of Set 12 | chapleau
# Processing Record 34 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 35 of Set 12 | hobyo
# Processing Record 36 of Set 12 | asau
# Processing Record 37 of Set 12 | kapuskasing
# Processing Record 38 of Set 12 | formiga
# Processing Record 39 of Set 12 | lewisville
# Processing Record 40 of Set 12 | lityn
# Processing Record 41 of Set 12 | araouane
# Processing Record 42 of Set 12 | belaya gora
# Processing Record 43 of Set 12 | sterling
# Processing Record 44 of Set 12 | viedma
# Processing Record 45 of Set 12 | rio grande
# Processing Record 46 of Set 12 | hammerfest
# Processing Record 47 of Set 12 | yar-sale
# Processing Record 48 of Set 12 | bara
# Processing Record 49 of Set 12 | morant bay
# Processing Record 50 of Set 12 | teshie
# Processing Record 1 of Set 13 | klyuchi
# Processing Record 2 of Set 13 | zverinogolovskoye
# Processing Record 3 of Set 13 | lunel
# Processing Record 4 of Set 13 | tejupilco
# City not found. Skipping...
# Processing Record 5 of Set 13 | kangaatsiaq
# Processing Record 6 of Set 13 | samarai
# Processing Record 7 of Set 13 | jiwani
# Processing Record 8 of Set 13 | obidos
# Processing Record 9 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 13 | darlawn
# Processing Record 11 of Set 13 | amazar
# Processing Record 12 of Set 13 | ha tinh
# Processing Record 13 of Set 13 | tazovskiy
# Processing Record 14 of Set 13 | chardara
# Processing Record 15 of Set 13 | lamar
# Processing Record 16 of Set 13 | uruzgan
# Processing Record 17 of Set 13 | westport
# Processing Record 18 of Set 13 | tucurui
# Processing Record 19 of Set 13 | valparaiso
# Processing Record 20 of Set 13 | gijon
# Processing Record 21 of Set 13 | bang saphan
# Processing Record 22 of Set 13 | lamu
# Processing Record 23 of Set 13 | saint-georges
# Processing Record 24 of Set 13 | pangody
# Processing Record 25 of Set 13 | wukari
# Processing Record 26 of Set 13 | elk city
# Processing Record 27 of Set 13 | santa cruz de la palma
# Processing Record 28 of Set 13 | iralaya
# Processing Record 29 of Set 13 | meulaboh
# Processing Record 30 of Set 13 | brufut
# Processing Record 31 of Set 13 | mago
# Processing Record 32 of Set 13 | kiunga
# Processing Record 33 of Set 13 | tateyama
# Processing Record 34 of Set 13 | bonthe
# Processing Record 35 of Set 13 | cukai
# Processing Record 36 of Set 13 | ambilobe
# Processing Record 37 of Set 13 | klenovyy
# Processing Record 38 of Set 13 | ulety
# Processing Record 39 of Set 13 | monteagudo
# Processing Record 40 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 13 | jinchengjiang
# City not found. Skipping...
# Processing Record 42 of Set 13 | sun valley
# Processing Record 43 of Set 13 | vallenar
# Processing Record 44 of Set 13 | narsipatnam
# Processing Record 45 of Set 13 | lososina
# Processing Record 46 of Set 13 | lahaina
# Processing Record 47 of Set 13 | bay roberts
# Processing Record 48 of Set 13 | santa isabel do rio negro
# Processing Record 49 of Set 13 | arinos
# Processing Record 50 of Set 13 | uspenskaya
# Processing Record 1 of Set 14 | cerrito
# Processing Record 2 of Set 14 | sokoni
# Processing Record 3 of Set 14 | tazmalt
# Processing Record 4 of Set 14 | birigui
# Processing Record 5 of Set 14 | inhambane
# Processing Record 6 of Set 14 | leh
# Processing Record 7 of Set 14 | dapdap
# Processing Record 8 of Set 14 | nurota
# Processing Record 9 of Set 14 | kalavrita
# City not found. Skipping...
# Processing Record 10 of Set 14 | killybegs
# Processing Record 11 of Set 14 | addi ugri
# City not found. Skipping...
# Processing Record 12 of Set 14 | ganzhou
# Processing Record 13 of Set 14 | garowe
# Processing Record 14 of Set 14 | moron
# Processing Record 15 of Set 14 | kamyshevatskaya
# Processing Record 16 of Set 14 | kattivakkam
# Processing Record 17 of Set 14 | vanavara
# Processing Record 18 of Set 14 | abha
# Processing Record 19 of Set 14 | jiblah
# Processing Record 20 of Set 14 | batavia
# Processing Record 21 of Set 14 | jishou
# Processing Record 22 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 14 | krasnoselkup
# Processing Record 24 of Set 14 | luderitz
# Processing Record 25 of Set 14 | general roca
# Processing Record 26 of Set 14 | fall river
# Processing Record 27 of Set 14 | shellbrook
# Processing Record 28 of Set 14 | zyryanka
# Processing Record 29 of Set 14 | broome
# Processing Record 30 of Set 14 | tecoanapa
# Processing Record 31 of Set 14 | adrar
# Processing Record 32 of Set 14 | bowen
# Processing Record 33 of Set 14 | toulepleu
# City not found. Skipping...
# Processing Record 34 of Set 14 | sabalgarh
# Processing Record 35 of Set 14 | shakhtinsk
# Processing Record 36 of Set 14 | pangnirtung
# Processing Record 37 of Set 14 | egvekinot
# Processing Record 38 of Set 14 | princeton
# Processing Record 39 of Set 14 | sistranda
# Processing Record 40 of Set 14 | pechenga
# Processing Record 41 of Set 14 | buy
# Processing Record 42 of Set 14 | bundu
# Processing Record 43 of Set 14 | shimoda
# Processing Record 44 of Set 14 | solenzo
# Processing Record 45 of Set 14 | poltavka
# Processing Record 46 of Set 14 | finnsnes
# Processing Record 47 of Set 14 | lander
# Processing Record 48 of Set 14 | jiayuguan
# Processing Record 49 of Set 14 | yuancheng
# Processing Record 50 of Set 14 | tacuarembo
# Processing Record 1 of Set 15 | yatou
# Processing Record 2 of Set 15 | ta khmau
# Processing Record 3 of Set 15 | barmer
# Processing Record 4 of Set 15 | orje
# Processing Record 5 of Set 15 | sayyan
# Processing Record 6 of Set 15 | obo
# Processing Record 7 of Set 15 | wanxian
# Processing Record 8 of Set 15 | hurghada
# Processing Record 9 of Set 15 | labuan
# Processing Record 10 of Set 15 | kosh-agach
# Processing Record 11 of Set 15 | betanzos
# Processing Record 12 of Set 15 | mascota
# Processing Record 13 of Set 15 | severodvinsk
# Processing Record 14 of Set 15 | natal
# Processing Record 15 of Set 15 | veraval
# Processing Record 16 of Set 15 | nesebar
# Processing Record 17 of Set 15 | innisfail
# Processing Record 18 of Set 15 | omsukchan
# Processing Record 19 of Set 15 | fort nelson
# Processing Record 20 of Set 15 | putla
# City not found. Skipping...
# Processing Record 21 of Set 15 | yakeshi
# Processing Record 22 of Set 15 | vogar
# Processing Record 23 of Set 15 | mildura
# Processing Record 24 of Set 15 | urumqi
# Processing Record 25 of Set 15 | ciudad real
# Processing Record 26 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 15 | gazojak
# Processing Record 28 of Set 15 | paidha
# Processing Record 29 of Set 15 | ust-maya
# Processing Record 30 of Set 15 | toamasina
# Processing Record 31 of Set 15 | urrao
# Processing Record 32 of Set 15 | olafsvik
# Processing Record 33 of Set 15 | miri
# Processing Record 34 of Set 15 | machali
# Processing Record 35 of Set 15 | karuzi
# Processing Record 36 of Set 15 | alegrete
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mataura -46.1927  168.8643     46.47        86          72
# 1         Knysna -34.0363   23.0471     52.56        90           9
# 2       Thompson  55.7435  -97.8558     26.04        70          12
# 3      Kisangani   0.5167   25.2000     69.91        99         100
# 4        Kichera  55.9375  110.0997     30.74        63          60
# 5          Balad  34.0164   44.1453     81.68        17           0
# 6   Punta Arenas -53.1500  -70.9167     42.91        81           0
# 7  Mount Gambier -37.8333  140.7667     64.31        82         100
# 8       Hermanus -34.4187   19.2345     54.77        82          15
# 9    Clyde River  70.4692  -68.5914     25.03        80         100
#
#    Wind Speed Country Weather Description
# 0        9.53      NZ       broken clouds
# 1        5.28      ZA           clear sky
# 2        5.21      CA          few clouds
# 3        1.59      CD     overcast clouds
# 4        1.23      RU       broken clouds
# 5        4.70      IQ           clear sky
# 6        9.22      CL           clear sky
# 7       18.41      AU     overcast clouds
# 8       13.53      ZA          few clouds
# 9       24.16      CA          light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Country                 object
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
